# %%
import random
import numpy as np                                      # Requer instalacao (via 'pip install numpy')
import pandas as pd                                     # Requer instalacao (via 'pip install wheel' e 'pip install pandas')
import matplotlib.pyplot as plt                         # Requer instalacao (via 'pip install seaborn')
import seaborn as sns                                   # Requer instalacao (via 'pip install matplotlib')
from sklearn import preprocessing                       # Requer instalacao (via 'pip install scikit-learn')
from sklearn.preprocessing import StandardScaler        # Requer instalacao (via 'pip install scikit-learn')
from sklearn.decomposition import PCA                   # Requer instalacao (via 'pip install scikit-learn')
from csv import DictReader
from os import path

##
#
#   Definicoes iniciais (caminho de arquivos raíz, encoding de caracteres no console)
#
##

# Aplicar conforme necessário

# pathBase = path.dirname( __file__ )
pathBase = path.dirname( "c:\\Users\\ivo_a\\Documents\\EACH\\2022-2\\MQA\\TrabalhoFinal\\metodos_quantitativos\\regressao_linear\\regressao_linear.py" )
# sys.stdout = io.TextIOWrapper( sys.stdout.buffer,encoding='utf8' )

##
#
#   Obtenção dos modelos
#
##

anoOuTotal = "2015"
nomeDoArquivoDeInstituicoes = "Publicacoes_Instituicoes_" + anoOuTotal + ".tsv"
nomeDoArquivoDeIndicadores = "Indicadores_Socioeconomicos_" + anoOuTotal + ".tsv"

filepath = path.abspath( path.join(pathBase, "..", "..", "dados", "4_final", "instituicoes", nomeDoArquivoDeInstituicoes))
with open(filepath, 'r', encoding='utf8') as file:
    dictReader = DictReader(file, delimiter='\t')
    listaInstituicoes = list(dictReader)

filepath = path.abspath( path.join(pathBase, "..", "..", "dados", "4_final", "regioes", "microrregioes", nomeDoArquivoDeIndicadores))
with open(filepath, 'r', encoding='utf8') as file:
    dictReader = DictReader(file, delimiter='\t')
    listaIndicadoresMicrorregioes = list(dictReader)

##
#
#   Análise de Componentes Principais
#
##

#   Calculo da produção acadêmica em cada região

for microrregiao in listaIndicadoresMicrorregioes :
    microrregiao["Publicacoes_Disciplina_Biologia"] = 0
    microrregiao["Publicacoes_Disciplina_Biotecnologia"] = 0
    microrregiao["Publicacoes_Disciplina_Especialidades_Medicas"] = 0
    microrregiao["Publicacoes_Disciplina_Engenharias_Civil_Mecanica_e_Quimica"] = 0
    microrregiao["Publicacoes_Disciplina_Quimica"] = 0
    microrregiao["Publicacoes_Disciplina_Ciencias_da_Natureza"] = 0
    microrregiao["Publicacoes_Disciplina_Engenharia_Eletrica_e_Ciencias_da_Computacao"] = 0
    microrregiao["Publicacoes_Disciplina_Pesquisas_Neurologicas"] = 0
    microrregiao["Publicacoes_Disciplina_Humanas"] = 0
    microrregiao["Publicacoes_Disciplina_Doencas_Infecciosas"] = 0
    microrregiao["Publicacoes_Disciplina_Matematica_e_Fisica"] = 0
    microrregiao["Publicacoes_Disciplina_Profissionais_da_Saude"] = 0
    microrregiao["Publicacoes_Disciplina_Ciencias_Sociais"] = 0

for instituicao in listaInstituicoes :
    idMicrorregiao = int(instituicao["ID_da_microregiao"])
    for microrregiao in listaIndicadoresMicrorregioes :
        if idMicrorregiao == int(microrregiao["ID_da_microregiao"]) :
            microrregiao["Publicacoes_Disciplina_Biologia"] += int(instituicao["Publicacoes_Disciplina_Biologia"])
            microrregiao["Publicacoes_Disciplina_Biotecnologia"] += int(instituicao["Publicacoes_Disciplina_Biotecnologia"])
            microrregiao["Publicacoes_Disciplina_Especialidades_Medicas"] += int(instituicao["Publicacoes_Disciplina_Especialidades_Medicas"])
            microrregiao["Publicacoes_Disciplina_Engenharias_Civil_Mecanica_e_Quimica"] += int(instituicao["Publicacoes_Disciplina_Engenharias_Civil_Mecanica_e_Quimica"])
            microrregiao["Publicacoes_Disciplina_Quimica"] += int(instituicao["Publicacoes_Disciplina_Quimica"])
            microrregiao["Publicacoes_Disciplina_Ciencias_da_Natureza"] += int(instituicao["Publicacoes_Disciplina_Ciencias_da_Natureza"])
            microrregiao["Publicacoes_Disciplina_Engenharia_Eletrica_e_Ciencias_da_Computacao"] += int(instituicao["Publicacoes_Disciplina_Engenharia_Eletrica_e_Ciencias_da_Computacao"])
            microrregiao["Publicacoes_Disciplina_Pesquisas_Neurologicas"] += int(instituicao["Publicacoes_Disciplina_Pesquisas_Neurologicas"])
            microrregiao["Publicacoes_Disciplina_Humanas"] += int(instituicao["Publicacoes_Disciplina_Humanas"])
            microrregiao["Publicacoes_Disciplina_Doencas_Infecciosas"] += int(instituicao["Publicacoes_Disciplina_Doencas_Infecciosas"])
            microrregiao["Publicacoes_Disciplina_Matematica_e_Fisica"] += int(instituicao["Publicacoes_Disciplina_Matematica_e_Fisica"])
            microrregiao["Publicacoes_Disciplina_Profissionais_da_Saude"] += int(instituicao["Publicacoes_Disciplina_Profissionais_da_Saude"])
            microrregiao["Publicacoes_Disciplina_Ciencias_Sociais"] += int(instituicao["Publicacoes_Disciplina_Ciencias_Sociais"])
            break

#   Categorização da atividade economica

for microrregiao in listaIndicadoresMicrorregioes :
    microrregiao["Atividade_primaria"] = "NONE"

for microrregiao in listaIndicadoresMicrorregioes :
    dictValores = {
        "valorAgropecuaria" : microrregiao["Valor_bruto_agropecuaria"],
        "valorIndustria" : microrregiao["Valor_bruto_industria"],
        "valorServicos" : microrregiao["Valor_bruto_servicos"],
        "valorAdministracao" : microrregiao["Valor_bruto_administracao"]
    }

    valorMaximo = max(dictValores, key=dictValores.get)

    if valorMaximo == "valorAgropecuaria" :
        microrregiao["Atividade_primaria"] = "AGROPECUARIA"
    elif valorMaximo == "valorIndustria" :
        microrregiao["Atividade_primaria"] = "INDUSTRIA"
    elif valorMaximo == "valorServicos" :
        microrregiao["Atividade_primaria"] = "SERVICOS"
    elif valorMaximo == "valorAdministracao" :
        microrregiao["Atividade_primaria"] = "ADMINISTRACAO"

#   Aplicação da ACP

dataframeMicrorregioes = pd.DataFrame(listaIndicadoresMicrorregioes)
dataframeMicrorregioes.drop(
    columns=["nome_da_microrregiao"],
    axis=1,
    inplace=True
)
dataframeMicrorregioes.drop(
    columns=["Atividade_primaria"],
    axis=1,
    inplace=True
)
for indice in dataframeMicrorregioes.keys() :
    dataframeMicrorregioes[indice] = pd.to_numeric(dataframeMicrorregioes[indice])


corr = dataframeMicrorregioes.corr()

# heatmap = sns.heatmap(corr,
#     xticklabels=False,
#     yticklabels=False,
#     cmap="YlGnBu"
# )

x = dataframeMicrorregioes.values

scaler = StandardScaler().fit(x)
scaled_x = scaler.transform(x)

listaNomes = []
for microrregiao in listaIndicadoresMicrorregioes:
    listaNomes.append( microrregiao["nome_da_microrregiao"] )

dataframeMicrorregioes2 = pd.DataFrame( 
    data=scaled_x,
    columns=dataframeMicrorregioes.columns,
    index=listaNomes
)

pca = PCA(n_components=2)
pca_decomp = pca.fit(scaled_x)
pca_x = pca.fit_transform(scaled_x)

pca_x
principalDf = pd.DataFrame( 
    data=pca_x,
    columns=['PC1','PC2'],
    index=dataframeMicrorregioes2.index
)

# fig, ax = plt.subplots(1,1)
# ax.scatter(principalDf['PC1'],principalDf['PC2'])
# for index, series in principalDf.iterrows():
#     ax.text(series[0]+0.2,series[1]+0.2, index)

# ax.set_ylim(-15,15)
# ax.set_xlim(-15,80)
# ax.grid()

x = pd.DataFrame(
    pca_decomp.components_, 
    columns=dataframeMicrorregioes2.columns
)
pd.set_option('display.max_rows', 310)
x.transpose()
# Out:
#                                                            0             1
# ID_da_microregiao                                   0.006752 -1.251103e-02
# Valor_bruto_agropecuaria                            0.000588 -2.473639e-03
# Valor_bruto_industria                               0.065715  1.877765e-02
# Valor_bruto_servicos                                0.067667 -1.964073e-02
# Valor_bruto_administracao                           0.053190  1.018020e-01
# Valor_bruto_total                                   0.068290  5.405466e-03
# Impostos                                            0.067472  4.949561e-03
# PIB                                                 0.068227  5.331400e-03
# Populacao                                           0.068105  4.492999e-02
# PIB_per_capita                                      0.019651 -1.446278e-02
# Produção de Lavouras Temporárias                    0.003895 -5.807002e-03
# Horticultura e Floricultura                         0.020060 -2.148718e-02
# Produção de Lavouras Permanentes                    0.002307 -4.533560e-03
# Produção de Sementes e Mudas Certificadas           0.014834 -1.787070e-03
# Pecuária                                            0.003094  1.109869e-02
# Atividades de Apoio à Agricultura e à Pecuária      0.014283  3.356445e-03
# Caça e Serviços Relacionados                        0.006202  1.462823e-02
# Produção Florestal - Florestas Plantadas            0.008119 -2.083525e-02
# Produção Florestal - Florestas Nativas              0.000839  1.082678e-02
# Atividades de Apoio à Produção Florestal            0.012082 -2.369448e-03
# Pesca                                               0.014353  9.865126e-02
# AqüIcultura                                         0.009098  1.697067e-02
# Extração de Carvão Mineral                          0.011359  1.189819e-02
# Extração de Petróleo e Gás Natural                  0.033568  1.920500e-01
# Extração de Minério de Ferro                        0.023962  4.933682e-02
# Extração de Minerais Metálicos Não-Ferrosos         0.024730  6.693857e-02
# Extração de Pedra, Areia e Argila                   0.026849  3.247684e-02
# Extração de Outros Minerais Não-Metálicos           0.021004  1.884753e-02
# Atividades de Apoio à Extração de Petróleo e Gá...  0.021003  1.460252e-01
# Atividades de Apoio à Extração de Minerais, Exc...  0.028809  6.290749e-02
# Abate e Fabricação de Produtos de Carne             0.046591 -9.622168e-03
# Preservação do Pescado e Fabricação de Produtos...  0.014406  4.445059e-02
# Fabricação de Conservas de Frutas, Legumes e Ou...  0.038572  1.499120e-02
# Fabricação de óleos e Gorduras Vegetais e Animais   0.025243 -3.422899e-02
# Laticínios                                          0.050331  6.251096e-02
# Moagem, Fabricação de Produtos Amiláceos e de A...  0.035777 -1.830345e-04
# Fabricação e Refino de Açúcar                       0.020408 -3.637383e-03
# Torrefação e Moagem de Café                         0.019684  1.329447e-02
# Fabricação de Outros Produtos Alimentícios          0.061177  2.447899e-02
# Fabricação de Bebidas Alcoólicas                    0.021255 -1.759891e-02
# Fabricação de Bebidas Não-Alcoólicas                0.041826  8.262364e-02
# Processamento Industrial do Fumo                    0.000563 -5.659024e-03
# Fabricação de Produtos do Fumo                      0.020952 -1.061448e-03
# Preparação e Fiação de Fibras Têxteis               0.038388 -5.619145e-02
# Tecelagem, Exceto Malha                             0.023423 -4.529585e-02
# Fabricação de Tecidos de Malha                      0.030624 -7.577247e-02
# Acabamentos em Fios, Tecidos e Artefatos Têxteis    0.039405 -5.042886e-02
# Fabricação de Artefatos Têxteis, Exceto Vestuário   0.045417 -5.964359e-02
# Confecção de Artigos do Vestuário e Acessórios      0.058771 -6.589706e-02
# Fabricação de Artigos de Malharia e Tricotagem      0.007468 -9.882293e-03
# Curtimento e Outras Preparações de Couro            0.019090 -1.431882e-02
# Fabricação de Artigos para Viagem e de Artefato...  0.052879 -1.768116e-02
# Fabricação de Calçados                              0.012678 -1.378364e-02
# Fabricação de Partes para Calçados, de Qualquer...  0.012123 -1.641232e-02
# Desdobramento de Madeira                            0.007234 -9.245942e-03
# Fabricação de Produtos de Madeira, Cortiça e Ma...  0.045865 -1.588356e-02
# Fabricação de Celulose e Outras Pastas para a F...  0.039595  3.048447e-03
# Fabricação de Papel, Cartolina e Papel-Cartão       0.041035 -2.592796e-02
# Fabricação de Embalagens de Papel, Cartolina, P...  0.065020 -5.759150e-02
# Fabricação de Produtos Diversos de Papel, Carto...  0.066798 -6.117760e-02
# Atividade de Impressão                              0.068505  1.569559e-02
# Serviços de Pré-Impressão e Acabamentos Gráficos    0.066824 -5.583765e-02
# Reprodução de Materiais Gravados em Qualquer Su...  0.062117  6.148934e-02
# Coquerias                                           0.002957  8.762124e-03
# Fabricação de Produtos Derivados do Petróleo        0.058858  7.805894e-02
# Fabricação de Biocombustíveis                       0.015754 -4.011076e-03
# Fabricação de Produtos Químicos Inorgânicos         0.056879 -1.458443e-02
# Fabricação de Produtos Químicos Orgânicos           0.063036 -6.368667e-02
# Fabricação de Resinas e Elastômeros                 0.061842 -7.887838e-02
# Fabricação de Fibras Artificiais e Sintéticas       0.050798 -8.429671e-02
# Fabricação de Defensivos Agrícolas e Desinfesta...  0.046283 -2.881009e-02
# Fabricação de Sabões, Detergentes, Produtos de ...  0.067337 -1.832395e-02
# Fabricação de Tintas, Vernizes, Esmaltes, Lacas...  0.060880 -2.872124e-04
# Fabricação de Produtos e Preparados Químicos Di...  0.064788 -6.524476e-02
# Fabricação de Produtos Farmoquímicos                0.053018  7.286215e-02
# Fabricação de Produtos Farmacêuticos                0.064759  2.008195e-03
# Fabricação de Produtos de Borracha                  0.064448 -8.542271e-02
# Fabricação de Produtos de Material Plástico         0.065050 -8.693058e-02
# Fabricação de Vidro e de Produtos do Vidro          0.065561 -3.618823e-02
# Fabricação de Cimento                               0.033687  8.658838e-02
# Fabricação de Artefatos de Concreto, Cimento, F...  0.051098  3.812757e-02
# Fabricação de Produtos Cerâmicos                    0.021662 -1.346402e-03
# Aparelhamento de Pedras e Fabricação de Outros ...  0.039110  2.323004e-02
# Produção de Ferro-Gusa e de Ferroligas              0.020438 -1.326200e-02
# Siderurgia                                          0.062569 -8.572956e-02
# Produção de Tubos de Aço, Exceto Tubos sem Costura  0.061440 -8.562148e-02
# Metalurgia dos Metais Não-Ferrosos                  0.065043 -6.752360e-02
# Fundição                                            0.052133 -6.005705e-02
# Fabricação de Estruturas Metálicas e Obras de C...  0.063383  1.102635e-02
# Fabricação de Tanques, Reservatórios Metálicos ...  0.050997 -6.468458e-02
# Forjaria, Estamparia, Metalurgia do Pó e Serviç...  0.061821 -8.368882e-02
# Fabricação de Artigos de Cutelaria, de Serralhe...  0.062808 -5.960278e-02
# Fabricação de Equipamento Bélico Pesado, Armas ...  0.042733 -8.705358e-02
# Fabricação de Produtos de Metal não Especificad...  0.063799 -9.416452e-02
# Fabricação de Componentes Eletrônicos               0.060129 -1.071072e-01
# Fabricação de Equipamentos de Informática e Per...  0.061657 -7.555084e-02
# Fabricação de Equipamentos de Comunicação           0.060526 -6.131116e-02
# Fabricação de Aparelhos de Recepção, Reprodução...  0.057465 -8.851479e-02
# Fabricação de Aparelhos e Instrumentos de Medid...  0.061986 -1.066597e-01
# Fabricação de Aparelhos Eletromédicos e Eletrot...  0.056395 -9.525183e-02
# Fabricação de Equipamentos e Instrumentos óptic...  0.059499 -9.609322e-03
# Fabricação de Mídias Virgens, Magnéticas e ópticas  0.040829 -5.354458e-02
# Fabricação de Geradores, Transformadores e Moto...  0.060956 -1.017788e-01
# Fabricação de Pilhas, Baterias e Acumuladores E...  0.030454 -4.692546e-02
# Fabricação de Equipamentos para Distribuição e ...  0.064790 -7.863613e-02
# Fabricação de Lâmpadas e Outros Equipamentos de...  0.062005 -9.631077e-02
# Fabricação de Eletrodomésticos                      0.061686 -8.018689e-02
# Fabricação de Equipamentos e Aparelhos Elétrico...  0.063326 -9.943688e-02
# Fabricação de Motores, Bombas, Compressores e E...  0.060452 -1.019901e-01
# Fabricação de Máquinas e Equipamentos de Uso Geral  0.064362 -8.783066e-02
# Fabricação de Tratores e de Máquinas e Equipame...  0.021350 -4.996158e-02
# Fabricação de Máquinas-Ferramenta                   0.057837 -1.087153e-01
# Fabricação de Máquinas e Equipamentos de Uso na...  0.057638  1.064842e-02
# Fabricação de Máquinas e Equipamentos de Uso In...  0.057913 -1.082409e-01
# Fabricação de Automóveis, Camionetas e Utilitários  0.059671 -7.747140e-02
# Fabricação de Caminhões e ônibus                    0.042947 -6.688759e-02
# Fabricação de Cabines, Carrocerias e Reboques p...  0.049859  8.793363e-03
# Fabricação de Peças e Acessórios para Veículos ...  0.059695 -1.221121e-01
# Recondicionamento e Recuperação de Motores para...  0.063063 -8.531911e-03
# Construção de Embarcações                           0.034594  1.568317e-01
# Fabricação de Veículos Ferroviários                 0.058564 -8.355569e-02
# Fabricação de Aeronaves                             0.024362 -1.556598e-03
# Fabricação de Veículos Militares de Combate         0.000000 -0.000000e+00
# Atividades de Serviços Financeiros não Especifi...  0.062775 -1.840767e-02
# Seguros de Vida e Não-Vida                          0.068812  3.306917e-03
# Seguros-Saúde                                       0.067199 -8.039894e-03
# Resseguros                                          0.058268  2.823954e-02
# Previdência Complementar                            0.062515  9.824797e-02
# Planos de Saúde                                     0.065322  5.725622e-02
# Atividades Auxiliares dos Serviços Financeiros      0.068722  1.857120e-02
# Atividades Auxiliares dos Seguros, da Previdênc...  0.067497 -4.570561e-02
# Atividades de Administração de Fundos por Contr...  0.062730 -2.519536e-02
# Atividades Imobiliárias de Imóveis Próprios         0.068510 -2.870023e-02
# Atividades Imobiliárias por Contrato ou Comissão    0.069361 -5.722321e-03
# Atividades Jurídicas                                0.069198  8.679073e-03
# Atividades de Contabilidade, Consultoria e Audi...  0.069874  8.645836e-03
# Sedes de Empresas e Unidades Administrativas Lo...  0.000000 -0.000000e+00
# Atividades de Consultoria em Gestão Empresarial     0.067450 -2.714585e-02
# Serviços de Arquitetura e Engenharia e Atividad...  0.068515  1.448907e-02
# Testes e Análises Técnicas                          0.066024  2.888592e-02
# Pesquisa e Desenvolvimento Experimental em Ciên...  0.063880  1.941416e-02
# Pesquisa e Desenvolvimento Experimental em Ciên...  0.065651  2.102422e-02
# Publicidade                                         0.068323 -3.624863e-02
# Pesquisas de Mercado e de Opinião Pública           0.062832 -7.115054e-02
# Design e Decoração de Interiores                    0.065663 -5.115309e-02
# Atividades Fotográficas e Similares                 0.068532 -2.640577e-02
# Atividades Profissionais, Científicas e Técnica...  0.068803 -3.298313e-03
# Atividades Veterinárias                             0.067228  3.166939e-02
# Locação de Meios de Transporte sem Condutor         0.064758  4.138260e-02
# Aluguel de Objetos Pessoais e Domésticos            0.067171  4.499897e-02
# Aluguel de Máquinas e Equipamentos sem Operador     0.067727  2.099512e-02
# Gestão de Ativos Intangíveis Não-Financeiros        0.066965 -2.542526e-02
# Seleção e Agenciamento de Mão-De-Obra               0.067799 -2.366795e-03
# Locação de Mão-De-Obra Temporária                   0.066355 -2.942236e-02
# Fornecimento e Gestão de Recursos Humanos para ...  0.067138  2.224098e-02
# Agências de Viagens e Operadores Turísticos         0.068984  1.117830e-02
# Serviços de Reservas e Outros Serviços de Turis...  0.065826 -1.344602e-02
# Atividades de Vigilância, Segurança Privada e T...  0.067891  2.384936e-02
# Atividades de Monitoramento de Sistemas de Segu...  0.068451 -3.632478e-02
# Atividades de Investigação Particular               0.058084  4.091572e-02
# Serviços Combinados para Apoio a Edifícios          0.063826  7.500003e-02
# Atividades de Limpeza                               0.069175  1.967812e-02
# Atividades Paisagísticas                            0.067380 -9.290483e-03
# Serviços de Escritório e Apoio Administrativo       0.066487 -6.558697e-02
# Atividades de Teleatendimento                       0.066869 -5.019154e-02
# Atividades de Organização de Eventos, Exceto Cu...  0.068893 -6.450634e-03
# Outras Atividades de Serviços Prestados Princip...  0.069295 -1.904228e-02
# Administração do Estado e da Política Econômica...  0.052907  6.372716e-02
# Serviços Coletivos Prestados Pela Administração...  0.038680  1.954123e-01
# Seguridade Social Obrigatória                       0.043989  5.058359e-02
# Educação Infantil e Ensino Fundamental              0.067909  3.981962e-02
# Ensino Médio                                        0.063231  9.336876e-02
# Educação Superior                                   0.068342  3.430178e-04
# Educação Profissional de Nível Técnico e Tecnol...  0.066455  4.202679e-02
# Atividades de Apoio à Educação                      0.053039  9.133030e-03
# Outras Atividades de Ensino                         0.069354  1.290266e-02
# Atividades de Atendimento Hospitalar                0.063194  7.998823e-02
# Serviços Móveis de Atendimento a Urgências e de...  0.066569 -4.454938e-03
# Atividades de Atenção Ambulatorial Executadas p...  0.069162  2.897868e-02
# Atividades de Serviços de Complementação Diagnó...  0.065978  7.876272e-02
# Atividades de Profissionais da área de Saúde, E...  0.067796  4.935989e-02
# Atividades de Apoio à Gestão de Saúde               0.066114  5.002633e-02
# Atividades de Atenção à Saúde Humana não Especi...  0.067710  3.470579e-02
# Atividades de Assistência a Idosos, Deficientes...  0.066410 -5.643754e-02
# Atividades de Assistência Psicossocial e à Saúd...  0.061273 -1.025145e-02
# Atividades de Assistência Social Prestadas em R...  0.067840 -2.530287e-02
# Serviços de Assistência Social sem Alojamento       0.065904 -6.921911e-02
# Atividades Artísticas, Criativas e de Espetáculos   0.064114  8.272354e-02
# Atividades Ligadas ao Patrimônio Cultural e Amb...  0.063933  7.225593e-02
# Atividades de Exploração de Jogos de Azar e Apo...  0.055796  1.004356e-01
# Atividades Esportivas                               0.068923  3.947174e-02
# Atividades de Recreação e Lazer                     0.068436  2.550098e-02
# Atividades de Organizações Associativas Patrona...  0.068611  4.572356e-03
# Atividades de Organizações Sindicais                0.064931  5.664280e-02
# Atividades de Associações de Defesa de Direitos...  0.068687  2.888558e-02
# Atividades de Organizações Associativas não Esp...  0.067384  5.972912e-02
# Reparação e Manutenção de Equipamentos de Infor...  0.069352  1.452709e-02
# Reparação e Manutenção de Objetos e Equipamento...  0.069701  7.375060e-03
# Outras Atividades de Serviços Pessoais              0.067710  5.328643e-02
# Serviços Domésticos                                 0.052876  4.693136e-02
# Organismos Internacionais e Outras Instituições...  0.046753  3.256865e-02
# {ñ class}                                           0.000000 -0.000000e+00
# Total_de_estabelecimentos                           0.070015  3.351030e-03
# Publicacoes_Disciplina_Biologia                     0.058316  6.445257e-02
# Publicacoes_Disciplina_Biotecnologia                0.062649  5.927081e-02
# Publicacoes_Disciplina_Especialidades_Medicas       0.064544  2.631034e-02
# Publicacoes_Disciplina_Engenharias_Civil_Mecani...  0.058952  9.004432e-02
# Publicacoes_Disciplina_Quimica                      0.061143  7.475383e-02
# Publicacoes_Disciplina_Ciencias_da_Natureza         0.054589  9.709139e-02
# Publicacoes_Disciplina_Engenharia_Eletrica_e_Ci...  0.061804  6.846342e-02
# Publicacoes_Disciplina_Pesquisas_Neurologicas       0.064511  1.996627e-02
# Publicacoes_Disciplina_Humanas                      0.062812  3.448819e-02
# Publicacoes_Disciplina_Doencas_Infecciosas          0.063630  2.806629e-02
# Publicacoes_Disciplina_Matematica_e_Fisica          0.059320  9.152977e-02
# Publicacoes_Disciplina_Profissionais_da_Saude       0.064380  3.382901e-02
# Publicacoes_Disciplina_Ciencias_Sociais             0.061741  6.812125e-02
